# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pathlib as Path

# %%
cwd=os.getcwd()
print(cwd)
ds_path=os.path.join(cwd,"model_train\dataset\raw_dataset.csv")
print(ds_path)
#df=pd.read_csv()
# Out:
# c:\Users\PIYUSH\Documents\SentinelAi\SwarmGuard-AI\model_train\scripts
# aw_dataset.csvH\Documents\SentinelAi\SwarmGuard-AI\model_train\scripts\model_train\dataset

# %%
#INPUT_DATASET = Path("dataset/raw_dataset.csv")

ds=os.path.join(cwd,"..","dataset")
print(ds)
# Out:
# c:\Users\PIYUSH\Documents\SentinelAi\SwarmGuard-AI\model_train\scripts\..\dataset
